# %%
#the first thing we need to do is grab FIFA stats for every player

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'CompleteDataset.csv',
#  'FIFA_for_Game_Prediction.ipynb',
#  'PlayerAttributeData.csv',
#  'PlayerPersonalData.csv',
#  'PlayerPlayingPositionData.csv',
#  'Untitled.ipynb']

# %%
import pandas as pd
Player_attr = pd.read_csv('PlayerAttributeData.csv')
Player_attr.head()
# Out:
# C:\Users\Tyler\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (11,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0 Acceleration Aggression Agility Balance Ball control Composure  \
# 0           0           89         63      89      63           93        95
# 1           1           92         48      90      95           95        96
# 2           2           94         56      96      82           95        92
# 3           3           88         78      86      60           91        83
# 4           4           58         29      52      35           48        70
#
#   Crossing Curve Dribbling   ...   Reactions Short passing Shot power  \
# 0       85    81        91   ...          96            83         94
# 1       77    89        97   ...          95            88         85
# ...

# %%
Player_pers = pd.read_csv('PlayerPersonalData.csv')
Player_pers.head(100)
# Out:
#     Unnamed: 0  Unnamed: 0.1      ID               Name  Age  \
# 0            0             0   20801  Cristiano Ronaldo   32
# 1            1             1  158023           L. Messi   30
# 2            2             2  190871             Neymar   25
# 3            3             3  176580          L. Suárez   30
# 4            4             4  167495           M. Neuer   31
# 5            5             5  188545     R. Lewandowski   28
# 6            6             6  193080             De Gea   26
# 7            7             7  183277          E. Hazard   26
# 8            8             8  182521           T. Kroos   27
# 9            9             9  167664         G. Higuaín   29
# 10          10            10  155862       Sergio Ramos   31
# 11          11            11  192985       K. De Bruyne   26
# 12          12            12  192119        T. Courtois   25
# 13          13            13  184941         A. Sánchez   28
# ...

# %%
list(Player_attr.columns.values)
# Out:
# ['Unnamed: 0',
#  'Acceleration',
#  'Aggression',
#  'Agility',
#  'Balance',
#  'Ball control',
#  'Composure',
#  'Crossing',
#  'Curve',
#  'Dribbling',
#  'Finishing',
#  'Free kick accuracy',
#  'GK diving',
#  'GK handling',
#  'GK kicking',
#  'GK positioning',
#  'GK reflexes',
#  'Heading accuracy',
#  'ID',
#  'Interceptions',
#  'Jumping',
#  'Long passing',
#  'Long shots',
#  'Marking',
#  'Penalties',
#  'Positioning',
#  'Reactions',
#  'Short passing',
#  'Shot power',
#  'Sliding tackle',
#  'Sprint speed',
#  'Stamina',
#  'Standing tackle',
#  'Strength',
#  'Vision',
#  'Volleys']

# %%
Player_attr['Unnamed: 0'].unique()
# Out:
# array([    0,     1,     2, ..., 17978, 17979, 17980], dtype=int64)

# %%
Player_stats_total = pd.merge(Player_attr, Player_pers, on = 'Unnamed: 0')

# %%
Player_stats_total.head()
# Out:
#    Unnamed: 0 Acceleration Aggression Agility Balance Ball control Composure  \
# 0           0           89         63      89      63           93        95
# 1           1           92         48      90      95           95        96
# 2           2           94         56      96      82           95        92
# 3           3           88         78      86      60           91        83
# 4           4           58         29      52      35           48        70
#
#   Crossing Curve Dribbling   ...    \
# 0       85    81        91   ...
# 1       77    89        97   ...
# 2       75    81        96   ...
# 3       77    86        86   ...
# 4       15    14        30   ...
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/48/18/players/20801.png    Portugal
# 1  https://cdn.sofifa.org/48/18/players/158023.png   Argentina
# 2  https://cdn.sofifa.org/48/18/players/190871.png      Brazil
# ...

# %%
import matplotlib

# %%
list(Player_stats_total.columns.values)
# Out:
# ['Unnamed: 0',
#  'Acceleration',
#  'Aggression',
#  'Agility',
#  'Balance',
#  'Ball control',
#  'Composure',
#  'Crossing',
#  'Curve',
#  'Dribbling',
#  'Finishing',
#  'Free kick accuracy',
#  'GK diving',
#  'GK handling',
#  'GK kicking',
#  'GK positioning',
#  'GK reflexes',
#  'Heading accuracy',
#  'ID_x',
#  'Interceptions',
#  'Jumping',
#  'Long passing',
#  'Long shots',
#  'Marking',
#  'Penalties',
#  'Positioning',
#  'Reactions',
#  'Short passing',
#  'Shot power',
#  'Sliding tackle',
#  'Sprint speed',
#  'Stamina',
#  'Standing tackle',
#  'Strength',
#  'Vision',
#  'Volleys',
#  'Unnamed: 0.1',
#  'ID_y',
#  'Name',
#  'Age',
#  'Photo',
#  'Nationality',
#  'Flag',
#  'Overall',
#  'Potential',
#  'Club',
#  'Club Logo',
#  'Value',
#  'Wage',
#  'Special']

# %%
import matplotlib.pyplot as plt

# %%
Player_stats_total['Wage'] = Player_stats_total['Wage'].str.replace('€', '')
Player_stats_total['Wage'] = Player_stats_total['Wage'].str.replace('K', '')

# %%
Player_stats_total['Wage'] = pd.to_numeric(Player_stats_total['Wage'])

# %%
plt.scatter(Player_stats_total['Overall'], Player_stats_total['Wage'])
plt.show()

# %%
import plotly

# %%
import plotly.plotly as py
import plotly.graph_objs as go

# %%
Player_stats_total['Name'].head()
# Out:
# 0    Cristiano Ronaldo
# 1             L. Messi
# 2               Neymar
# 3            L. Suárez
# 4             M. Neuer
# Name: Name, dtype: object

# %%
plotly.tools.set_credentials_file(username='tylerjrichards', api_key='eiDaruWtu0R3tnjxhMRa')

# %%
data = [go.Scatter(
            x= Player_stats_total['Overall'],
            y= Player_stats_total['Wage'],
            mode = 'markers',
            text = Player_stats_total['Name']
    )]

plotly.plotly.iplot(data, filename='Wage vs Overall FIFA')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~tylerjrichards/6.embed" height="525px" width="100%"></iframe>

# %%
#at the moment, we're only interested in the EPL
list(Player_stats_total['Club'].unique())
# Out:
# ['Real Madrid CF',
#  'FC Barcelona',
#  'Paris Saint-Germain',
#  'FC Bayern Munich',
#  'Manchester United',
#  'Chelsea',
#  'Juventus',
#  'Manchester City',
#  'Arsenal',
#  'Atlético Madrid',
#  'Borussia Dortmund',
#  'Milan',
#  'Tottenham Hotspur',
#  'Napoli',
#  'Inter',
#  'Liverpool',
#  'Roma',
#  'Beşiktaş JK',
#  'AS Monaco',
#  'Bayer 04 Leverkusen',
#  'AS Saint-Étienne',
#  'Athletic Club de Bilbao',
#  '1. FC Köln',
#  'Villarreal CF',
#  'FC Schalke 04',
#  'Olympique de Marseille',
#  'Atalanta',
#  'RB Leipzig',
#  'Real Sociedad',
#  'Torino',
#  'Sporting CP',
#  'Leicester City',
#  'Southampton',
#  'FC Porto',
#  'UD Las Palmas',
#  'Olympique Lyonnais',
#  'Lazio',
#  'Genoa',
#  'Everton',
#  'RC Celta de Vigo',
#  'Valencia CF',
#  nan,
#  'Sevilla FC',
#  'Toronto FC',
#  'Borussia Mönchengladbach',
#  'SL Benfica',
#  'RCD Espanyol',
#  'OGC Nice',
#  'Spartak Moscow',
#  'Swansea City',
#  'Sassuolo',
#  'TSG 1899 Hoffenheim',
#  'Stoke City',
# ...

# %%
epl_clubs = ['Manchester United', 'Chelsea', 'Manchester City',
 'Arsenal', 'Tottenham Hotspur', 'Leicester City',
 'Southampton', 'Everton', 'Swansea City', 'Stoke City', 'West Ham United', 'Bournemouth', 'Crystal Palace',
 'West Bromwich Albion', 'Burnley', 'Newcastle United', 'Liverpool', 'Huddersfield Town', 'Brighton & Hove Albion', 'Watford' ]
EPL_Player_stats = Player_stats_total.loc[Player_stats_total['Club'].isin(epl_clubs)]

# %%
len(EPL_Player_stats['Club'].unique())
# Out:
# 20

# %%
EPL_Player_stats.groupby(by = 'Club').mean()['Overall'].to_frame().sort_values('Overall', ascending = False)
# Out:
#                           Overall
# Club
# Manchester United       77.705882
# Chelsea                 76.666667
# Liverpool               75.875000
# Arsenal                 75.757576
# Everton                 74.727273
# Manchester City         74.121212
# Watford                 74.031250
# Tottenham Hotspur       73.375000
# Leicester City          72.000000
# Southampton             71.878788
# West Ham United         71.281250
# Swansea City            71.031250
# Newcastle United        70.727273
# Stoke City              70.636364
# Crystal Palace          70.606061
# Brighton & Hove Albion  70.333333
# Bournemouth             70.151515
# West Bromwich Albion    70.068966
# Burnley                 68.843750
# Huddersfield Town       66.878788

# %%
df['C'] =  df[['A', 'B']].avg(axis=1)

# %%
EPL_Player_stats
# Out:
#            Unnamed: 0 Acceleration Aggression Agility Balance Ball control  \
# 6                 6.0           57         38      60      43           42
# 7                 7.0           93         54      93      91           92
# 11               11.0           76         68      80      75           87
# 12               12.0           46         23      61      45           23
# 13               13.0           88         80      90      87           87
# 16               16.0           90         63      86      91           89
# 28               28.0           75         48      83      70           90
# 29               29.0           65         31      55      54           34
# 31               31.0           63         84      81      41           88
# 33               33.0           82         90      83      90           79
# 35               35.0           72         75      76      61           89
# ...

# %%
EPL_Player_stats.loc['Attacking'] = EPL_Player_stats[['Crossing', 'Finishing', 'Heading accuracy', 'Short passing', 'Volleys']].mean(axis = 0)
# Out:
# C:\Users\Tyler\Anaconda3\lib\site-packages\pandas\core\indexing.py:537: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
EPL_Player_stats['Attacking']
# Out:
# 6           NaN
# 7           NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 16          NaN
# 28          NaN
# 29          NaN
# 31          NaN
# 33          NaN
# 35          NaN
# 36          NaN
# 42          NaN
# 46          NaN
# 50          NaN
# 54          NaN
# 56          NaN
# 57          NaN
# 58          NaN
# 65          NaN
# 68          NaN
# 73          NaN
# 75          NaN
# 81          NaN
# 82          NaN
# 86          NaN
# 90          NaN
# 92          NaN
# 94          NaN
# 96          NaN
#              ..
# 16748       NaN
# 16796       NaN
# 16865       NaN
# 16890       NaN
# 16944       NaN
# 16957       NaN
# 16977       NaN
# 16999       NaN
# 17015       NaN
# 17034       NaN
# 17064       NaN
# 17071       NaN
# 17079       NaN
# 17084       NaN
# 17093       NaN
# 17208       NaN
# 17291       NaN
# 17315       NaN
# 17317       NaN
# 17346       NaN
# 17347       NaN
# 17423       NaN
# 17424       NaN
# 17472       NaN
# ...

# %%
EPL_Player_stats.loc[EPL_Player_stats['Club'] == 'Chelsea']
# Out:
#        Unnamed: 0 Acceleration Aggression Agility Balance Ball control  \
# 7               7           93         54      93      91           92
# 12             12           46         23      61      45           23
# 33             33           82         90      83      90           79
# 57             57           68         86      72      56           79
# 58             58           74         93      58      52           83
# 65             65           65         45      65      77           86
# 82             82           78         80      75      73           79
# 101           101           78         54      62      56           84
# 109           109           84         56      84      82           87
# 114           114           91         44      89      81           86
# 123           123           62         84      62      51           63
# 200           200           75         85      66      62           78
# ...
